# %% [markdown]
# # BeautifulSoup #4
# # 주식 일별 시세 가져오기
#
# 네이버 증권에서 제공하는 삼성전자 종목(005930)의 일별 시세를 가져와 보겠습니다.
#
# ![stock.PNG](attachment:stock.PNG)
# > 주소:https://finance.naver.com/item/sise.nhn?code=005930
#
# 위의 주소와 같이 뒷부분에 code=005930와 같이 종목코드를 입력해주면 해당 종목의 일별 시세를 볼 수 있습니다.

# %% [markdown]
# ## 원하는 데이터 추출하기
# 종목의 일별 시세 페이지에서 날짜, 종가, 거래량만 추출해서 출력해 보겠습니다.
#
# ![datachoice.png](attachment:datachoice.png)
#
# 위 그림과 같이 개발자 도구(F12)를 통해 소스를 보면 날짜, 종가, 거래량이 나온 부분을 찾을 수 있습니다.
#
# 'table','tr','td' 태그 안의 텍스트임을 알 수 있습니다.

# %% [markdown]
# ## 예제

# %%
import requests
from bs4 import BeautifulSoup

def print_stock_price(code, page_num):
    result = [[], [], []]
    
    for n in range(page_num):
        url = 'https://finance.naver.com/item/sise_day.nhn?code='+code+'&page='+str(n+1)
        r = requests.get(url)
        html = r.content
        soup = BeautifulSoup(html, 'html.parser')
        tr = soup.select('table > tr')
        
        for i in range(1, len(tr)-1):
            if tr[i].select('td')[0].text.strip():
                result[0].append(tr[i].select('td')[0].text.strip())
                result[1].append(tr[i].select('td')[1].text.strip())
                result[2].append(tr[i].select('td')[6].text.strip())
                
        for i in range(len(result[0])):
            print(result[0][i], result[1][i], result[2][i])
            
stock_code = '005930'
pages = 50

print_stock_price(stock_code, pages)

# %% [markdown]
# 날짜, 종가 ,거래량이 최근순으로 출력됩니다.

# %% [markdown]
# ## 설명

# %%
def print_stock_price(code, page_num):
    result = [[], [], []]

# %% [markdown]
# 종목의 코드와 페이지 수를 입력하는 함수를 만듭니다. result에는 날짜, 종가, 거래량이 추가됩니다.

# %%
for n in range(page_num):
    url = 'https://finance.naver.com/item/sise_day.nhn?code='+code+'&page='+str(n+1)
    r = requests.get(url)
    html = r.content
    soup = BeautifulSoup(html, 'html.parser')
    tr = soup.select('table > tr')

# %% [markdown]
# 주소 뒷부분에 &page=2와 같은 형식으로 연결해주면 해당 페이지의 일별 시세를 볼 수 있습니다.
#
# table 안의 tr 태그를 리스트형태로 가져옵니다.

# %%
for i in range(1, len(tr)-1):
    if tr[i].select('td')[0].text.strip():
        result[0].append(tr[i].select('td')[0].text.strip())
        result[1].append(tr[i].select('td')[1].text.strip())
        result[2].append(tr[i].select('td')[6].text.strip())

# %% [markdown]
# 첫번째 tr 태그는 th 태그가, 마지막 tr 태그는 페이지 넘버가 있어서 제외합니다
#
# text가 없는 row가 있습니다.
#
# text가 있는 row에 대해서 첫번째(날짜), 두번째(종가), 일곱번째(거래량) td 태그의 text를 가져옵니다.

# %%
stock_code = '005930'
pages = 50

print_stock_price(stock_code, pages)

# %% [markdown]
# 해당 종목의 코드와 50페이지를 입력합니다.

# %% [markdown]
# ## 결과
# 출력 결과는 아래와 같습니다.

# %%
print_stock_price(stock_code, pages)
# Out:
# 2019.11.18 53,500 2,236,947
# 2019.11.15 53,700 9,703,360
# 2019.11.14 52,800 12,010,018
# 2019.11.13 52,500 6,225,196
# 2019.11.12 52,600 6,576,148
# 2019.11.11 51,600 8,185,952
# 2019.11.08 52,100 11,603,290
# 2019.11.07 52,900 9,257,116
# 2019.11.06 53,300 14,361,133
# 2019.11.05 52,700 10,581,034
# 2019.11.18 53,500 2,236,947
# 2019.11.15 53,700 9,703,360
# 2019.11.14 52,800 12,010,018
# 2019.11.13 52,500 6,225,196
# 2019.11.12 52,600 6,576,148
# 2019.11.11 51,600 8,185,952
# 2019.11.08 52,100 11,603,290
# 2019.11.07 52,900 9,257,116
# 2019.11.06 53,300 14,361,133
# 2019.11.05 52,700 10,581,034
# 2019.11.04 52,300 13,012,411
# 2019.11.01 51,200 8,467,846
# 2019.10.31 50,400 10,304,777
# 2019.10.30 50,400 8,959,435
# 2019.10.29 51,100 7,581,629
# 2019.10.28 51,300 6,431,522
# 2019.10.25 50,900 7,879,897
# 2019.10.24 50,700 21,185,785
# 2019.10.23 51,200 8,663,880
# 2019.10.22 51,200 10,898,729
# 2019.11.18 53,500 2,236,947
# 2019.11.15 53,700 9,703,360
# ...

# %% [markdown]
# 2017년 11월 3일부터 2019년 11월 18일까지 일별시세와 거래량을 출력합니다.
